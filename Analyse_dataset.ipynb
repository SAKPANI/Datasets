# %%
import pandas as pd

# %%
data_dons = pd.read_csv("https://storage.data.gov.my/healthcare/blood_donations.csv")
data_dons.head()
# Out:
#          date blood_type  donations
# 0  2006-01-01        all        525
# 1  2006-01-02        all        227
# 2  2006-01-03        all        112
# 3  2006-01-04        all        391
# 4  2006-01-05        all        582

# %%
data_dons.rename({
    "blood_type" : "groupe_sanguins",
    "donations"  : "dons"
},inplace= True , axis= 1)

data_dons.head()
# Out:
#          date groupe_sanguins  dons
# 0  2006-01-01             all   525
# 1  2006-01-02             all   227
# 2  2006-01-03             all   112
# 3  2006-01-04             all   391
# 4  2006-01-05             all   582

# %%
data_dons.shape
# Out:
# (37795, 3)

# %%
data_dons.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37795 entries, 0 to 37794
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             37795 non-null  str
#  1   groupe_sanguins  37795 non-null  str
#  2   dons             37795 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 1.3 MB

# %%
#data_dons.to_csv("data_dons.csv", index = False)

# %%
df = pd.read_csv("transfusion.csv", encoding="latin1")

# Option B : Windows-1252 (Standard sous Windows)
#df = pd.read_csv("transfusion.csv", encoding="cp1252")

# %%
data1 = pd.read_csv("Data_sheet_1.csv")
data1.head()
# Out:
#          date  collected_total  collected_A collected_B collected_O  \
# 0   3/19/2012           3896.0       1224.0         996        1389
# 1   3/26/2012           3058.0        965.0         749        1081
# 2  04/02/2012           3055.0        923.0         851        1007
# 3  04/09/2012           2887.0        908.0         782         991
# 4   4/16/2012           2915.0        800.0         819        1046
#
#   collected_AB team_total Individual_donate  demand_total  demand_A  ...  \
# 0          287       1100              2796          4600      1400  ...
# 1          263       1115              1943          4300      1400  ...
# 2          274      399.5            2655.5          4600      1500  ...
# 3          206        505              2382          4700      1500  ...
# 4          250      543.5            2371.5          4700      1500  ...
#
#    platelet_collection_tx_units  platelet_collection_A  platelet_collection_B  \
# ...

# %%
data1.shape
# Out:
# (639, 29)

# %%
data1.columns
# Out:
# Index(['date', 'collected_total', 'collected_A', 'collected_B', 'collected_O',
#        'collected_AB', 'team_total', 'Individual_donate', 'demand_total',
#        'demand_A', 'demand_B', 'demand_O', 'demand_AB', 'supply_total',
#        'supply_A', 'supply_B', 'supply_O', 'supply_AB', 'platelet_collection',
#        'platelet_collection_tx_units', 'platelet_collection_A',
#        'platelet_collection_B', 'platelet_collection_O',
#        'platelet_collection_AB', 'platelet_supply', 'platelet_supply_A',
#        'platelet_supply_B', 'platelet_supply_O', 'platelet_supply_AB'],
#       dtype='str')

# %%
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          639 non-null    str
#  1   collected_total               639 non-null    float64
#  2   collected_A                   639 non-null    float64
#  3   collected_B                   639 non-null    str
#  4   collected_O                   639 non-null    str
#  5   collected_AB                  639 non-null    str
#  6   team_total                    615 non-null    str
#  7   Individual_donate             639 non-null    str
#  8   demand_total                  639 non-null    int64
#  9   demand_A                      639 non-null    int64
#  10  demand_B                      639 non-null    int64
#  11  demand_O                      639 non-null    int64
#  12  demand_AB                     639 non-null    int64
# ...

# %%
data1["date"] = pd.to_datetime(data1["date"])

# %%
data_ecart = data1['date'].sort_values().diff().value_counts()
data_ecart  #Ecart entre les differente jours de demandes
# Out:
# date
# 7 days     564
# 14 days     13
# 0 days      13
# 6 days      12
# 1 days      10
# 4 days       5
# 5 days       5
# 8 days       4
# 3 days       3
# 2 days       3
# 35 days      2
# 38 days      1
# 10 days      1
# 42 days      1
# 9 days       1
# Name: count, dtype: int64

# %%
data1["date"].duplicated().sum() #Verification des doublons des dates
# Out:
# np.int64(13)

# %%
# Vérifier les lignes ayant des dates répétées
doublons = data1[data1['date'].duplicated(keep=False)].sort_values('date')

print(doublons[['date', 'demand_total', 'supply_total', 'collected_total']].to_string()) # Est que les donnes des dates du meme jours se ressmenbles entres eux ??
# Out:
#           date  demand_total  supply_total  collected_total
# 145 2015-01-05          3450        3445.5          2726.65
# 184 2015-01-05          2910        2842.5          2392.20
# 146 2015-01-12          3350        3548.5          3903.15
# 185 2015-01-12          3950        3843.5          3522.00
# 147 2015-01-19          3550        3698.0          3256.15
# 186 2015-01-19          4080        4033.5          5189.80
# 148 2015-01-26          3100        3163.5          2149.90
# 187 2015-01-26          3880        3726.5          2976.60
# 288 2017-01-02          2150        2157.5          2077.70
# 249 2017-01-02          3340        3292.5          2629.95
# 250 2017-01-09          3350        3282.5          3001.45
# 289 2017-01-09          3700        3614.5          3172.35
# 251 2017-01-16          3050        3006.0          2002.85
# 290 2017-01-16          4050        3940.0          4509.05
# 252 2017-01-23          2550        2493.0          2538.85
# ...

# %% [markdown]
# Apres analyse on remarques les donnees de demandes , de collectes ... du meme jours ne se ressembles pas

# %%
data2 = pd.read_csv("Data_Sheet_2.CSV")
data2.head()
# Out:
#     Year   Quarter  Value of GDP in Provincial level  Primary industry   \
# 0  2014.0      1.0                           7768.46             274.21
# 1  2014.0      2.0                          10209.75             480.99
# 2  2014.0      3.0                           9843.98             398.21
# 3  2014.0      4.0                          12331.31             625.85
# 4  2015.0      1.0                           8342.38             278.19
#
#    Secondary industry  Tiertiary industry              Unit  \
# 0             3744.93             3749.32  100 million yuan
# 1             5170.42             4558.34  100 million yuan
# 2             4934.27             4511.50  100 million yuan
# 3             5303.11             6402.35  100 million yuan
# 4             3772.22             4291.97  100 million yuan
#
#    Numbers of health institutions  Numbers of medical staffs  \
# 0                         30360.0                   455704.0
# ...

# %%
data2.columns # Avoi datasheet deux nous donnne la provenance des collecte du jeux de donnes datasheet , en vrai c'est ce que je croix
# Out:
# Index(['Year ', 'Quarter', 'Value of GDP in Provincial level',
#        'Primary industry ', 'Secondary industry', 'Tiertiary industry', 'Unit',
#        'Numbers of health institutions', 'Numbers of medical staffs',
#        'Health staffs per thousand', 'Numbers of visits', 'Outpatient/ER',
#        'Population size', 'Male', 'Female', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='str')

# %%
data2.shape
# Out:
# (42, 26)
